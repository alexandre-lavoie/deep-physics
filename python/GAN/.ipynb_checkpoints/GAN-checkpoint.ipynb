# %% [markdown]
# # Imports

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Input, Concatenate
from tensorflow.keras.optimizers import Adam, RMSprop
import numpy as np
import matplotlib.pyplot as plt
import copy

# %% [markdown]
# # Global Variables

# %%
epochs = 500
batch_size = 16
number_of_particles = epochs * 2 * batch_size
dt = 0.1

# %% [markdown]
# # Classes

# %%
class Particle:
    def __str__(self):
        return "Position: %s, Velocity: %s, Accleration: %s" % (self.position, self.velocity, self.acceleration)
    
    def __repr__(self):
        return "Position: %s, Velocity: %s, Accleration: %s" % (self.position, self.velocity, self.acceleration)
    
    def __init__(self):
        self.position = np.array([np.random.sample()*2-1,np.random.sample()*2-1]) # Position X, Y
        self.velocity = np.array([np.random.sample()*2-1,np.random.sample()*2-1]) # Velocity X, Y
        self.acceleration = np.array([np.random.sample()*2-1,np.random.sample()*2-1]) # Acceleration X, Y
        
    def apply_physics(self,dt):
        nextParticle = copy.deepcopy(self) # Copy to retain initial values
        nextParticle.position += self.velocity * dt
        nextParticle.velocity += self.acceleration * dt
        return nextParticle
    
    def get_list(self):
        return [self.position[0],self.position[1],self.velocity[0], self.velocity[1], self.acceleration[0], self.acceleration[1]]
    
    def get_list_physics(self,dt):
        n = self.apply_physics(dt)
        return [self.position[0],self.position[1],self.velocity[0], self.velocity[1], self.acceleration[0], 
                self.acceleration[1], n.position[0], n.position[1], n.velocity[0], n.velocity[1]]

# %%
class GAN:
    def __init__(self,input_size,output_size,dropout=0.4):
        self.input_size = input_size
        self.output_size = output_size
        self.dropout = dropout
        self.generator = self.generator_network()
        self.discriminator = self.discriminator_network()
        self.adverserial = self.adverserial_network()
    
    def discriminator_trainable(self, val):
        self.discriminator.trainable = val
        for l in self.discriminator.layers:
            l.trainable = val
    
    def generator_network(self): # Generator : Object(6) - Dense - Object(4)
        self.g_input = Input(shape=(self.input_size,), name="Generator_Input")
        g = Dense(128, activation='relu')(self.g_input)
        g = Dropout(self.dropout)(g)
        g = Dense(256, activation='relu')(g)
        g = Dropout(self.dropout)(g)
        g = Dense(512, activation='relu')(g)
        g = Dropout(self.dropout)(g)
        g = Dense(256, activation='relu')(g)
        g = Dropout(self.dropout)(g)
        g = Dense(128, activation='relu')(self.g_input)
        g = Dropout(self.dropout)(g)
        self.g_output = Dense(self.output_size, activation='tanh', name="Generator_Output")(g) 
        m = Model(self.g_input, self.g_output, name="Generator")
        return m
    
    def discriminator_network(self): # Discriminator : Object(10) - Dense - Probability
        d_opt = RMSprop(lr=0.0002,decay=6e-8)
        d_input = Input(shape=(self.input_size+self.output_size,), name="Discriminator_Input")
        d = Dense(128, activation='relu')(d_input)
        d = Dense(256, activation='relu')(d)
        d = Dense(512, activation='relu')(d)
        d = Dense(256, activation='relu')(d)
        d = Dense(128, activation='relu')(d)
        d_output = Dense(1, activation='sigmoid', name="Discriminator_Output")(d)
        m = Model(d_input, d_output, name="Discriminator")
        m.compile(loss='binary_crossentropy', optimizer=d_opt)
        return m
    
    def adverserial_network(self): # Adverserial : Object(6) - Generator - Discriminator - Probability
        a_opt = RMSprop(lr=0.0001,decay=3e-8)
        d_input = Concatenate(name="Generator_Input_Output")([self.g_input,self.g_output])
        m=Model(self.g_input, self.discriminator(d_input))
        m.compile(loss='binary_crossentropy', optimizer=a_opt)
        return m
    
    def train_discriminator(self,val):
        self.discriminator.trainable = val
        for l in self.discriminator.layers:
            l.trainable = val
    
    def train(self, adverserial_set, discriminator_set, epochs, batch_size):
        
        losses = {"d":[], "g":[]}

        for i in range(epochs):
            
            batch = discriminator_set[int(i/2*batch_size/2):int((i/2+1)*batch_size/2)] # Gets a batch of real data
            
            for j in adverserial_set[int(i/2*batch_size/2):int((i/2+1)*batch_size/2)]: # Gets a batch of generated data
                n = copy.deepcopy(j)
                p = self.predict(j)
                for e in p:
                    n.append(e)
                batch.append(n)
            
            #self.train_discriminator(True) # Turns on discriminator weights
            
            output = np.zeros(batch_size) # Sets output weight 0 for real and 1 for fakes
            output[int(batch_size/2):] = 1
            
            losses["d"].append(self.discriminator.train_on_batch(np.array(batch), np.array(output))) # Train discriminator
            
            batch = adverserial_set[(i*batch_size):((i+1)*batch_size)] # Gets real data to train generator
            output = np.zeros(batch_size)
            
            #self.train_discriminator(False) # Turns off discriminator weights
            
            losses["g"].append(self.adverserial.train_on_batch(np.array(batch), np.array(output))) # Train generator
            
            print('Epoch %s - Adverserial Loss : %s, Discriminator Loss : %s' % (i+1, losses["g"][-1], losses["d"][-1]))
        
        self.generator.save("Generator.h5")
        self.discriminator.save("Discriminator.h5")
        
        return losses
    
    def predict(self, pred):
        return self.generator.predict(np.array(pred).reshape(-1,6))[0]

# %% [markdown]
# # Training Data

# %%
training_set = []
actual_set = []

for i in range(number_of_particles):
    p = Particle()
    if(i%2==0):
        training_set.append(p.get_list())
    else:
        actual_set.append(p.get_list_physics(dt))

# %% [markdown]
# # Training

# %%
network = GAN(input_size=6,output_size=4,dropout=0)

# %%
loss = network.train(adverserial_set=training_set,discriminator_set=actual_set,epochs=epochs,batch_size=batch_size)
# Out:
# Epoch 1 - Adverserial Loss : 0.7593789, Discriminator Loss : 0.7475223
# Epoch 2 - Adverserial Loss : 0.7363486, Discriminator Loss : 0.7152627
# Epoch 3 - Adverserial Loss : 0.75299, Discriminator Loss : 0.7028278
# Epoch 4 - Adverserial Loss : 0.73692214, Discriminator Loss : 0.7308773
# Epoch 5 - Adverserial Loss : 0.72971106, Discriminator Loss : 0.7396294
# Epoch 6 - Adverserial Loss : 0.7399001, Discriminator Loss : 0.7159431
# Epoch 7 - Adverserial Loss : 0.7122102, Discriminator Loss : 0.72455233
# Epoch 8 - Adverserial Loss : 0.67741907, Discriminator Loss : 0.7300263
# Epoch 9 - Adverserial Loss : 0.69089687, Discriminator Loss : 0.6907587
# Epoch 10 - Adverserial Loss : 0.7400292, Discriminator Loss : 0.6808979
# Epoch 11 - Adverserial Loss : 0.6905575, Discriminator Loss : 0.72096413
# Epoch 12 - Adverserial Loss : 0.7430903, Discriminator Loss : 0.7067504
# Epoch 13 - Adverserial Loss : 0.693717, Discriminator Loss : 0.67834234
# Epoch 14 - Adverserial Loss : 0.71504897, Discriminator Loss : 0.69044226
# Epoch 15 - Adverserial Loss : 0.6868428, Discriminator Loss : 0.67274487
# Epoch 16 - Adverserial Loss : 0.69872606, Discriminator Loss : 0.717549
# Epoch 17 - Adverserial Loss : 0.70728374, Discriminator Loss : 0.73356605
# Epoch 18 - Adverserial Loss : 0.6932973, Discriminator Loss : 0.714103
# Epoch 19 - Adverserial Loss : 0.71686286, Discriminator Loss : 0.7249904
# Epoch 20 - Adverserial Loss : 0.73018944, Discriminator Loss : 0.6872605
# Epoch 21 - Adverserial Loss : 0.6634453, Discriminator Loss : 0.6743562
# Epoch 22 - Adverserial Loss : 0.6609131, Discriminator Loss : 0.6800924
# Epoch 23 - Adverserial Loss : 0.7283291, Discriminator Loss : 0.7013742
# Epoch 24 - Adverserial Loss : 0.6518434, Discriminator Loss : 0.72981524
# Epoch 25 - Adverserial Loss : 0.7334709, Discriminator Loss : 0.7071216
# Epoch 26 - Adverserial Loss : 0.69444174, Discriminator Loss : 0.6683118
# Epoch 27 - Adverserial Loss : 0.66597664, Discriminator Loss : 0.69186884
# Epoch 28 - Adverserial Loss : 0.67883605, Discriminator Loss : 0.7491314
# Epoch 29 - Adverserial Loss : 0.69081795, Discriminator Loss : 0.72847164
# Epoch 30 - Adverserial Loss : 0.72118145, Discriminator Loss : 0.6957239
# Epoch 31 - Adverserial Loss : 0.71010685, Discriminator Loss : 0.71661556
# Epoch 32 - Adverserial Loss : 0.68772113, Discriminator Loss : 0.7518283
# Epoch 33 - Adverserial Loss : 0.65559185, Discriminator Loss : 0.7273774
# Epoch 34 - Adverserial Loss : 0.68523186, Discriminator Loss : 0.6829692
# Epoch 35 - Adverserial Loss : 0.65764725, Discriminator Loss : 0.7040707
# Epoch 36 - Adverserial Loss : 0.6613085, Discriminator Loss : 0.6986097
# Epoch 37 - Adverserial Loss : 0.7128384, Discriminator Loss : 0.70444375
# Epoch 38 - Adverserial Loss : 0.64628935, Discriminator Loss : 0.70457554
# Epoch 39 - Adverserial Loss : 0.6782367, Discriminator Loss : 0.6974317
# Epoch 40 - Adverserial Loss : 0.69403017, Discriminator Loss : 0.7191253
# Epoch 41 - Adverserial Loss : 0.7056082, Discriminator Loss : 0.7159554
# Epoch 42 - Adverserial Loss : 0.6533118, Discriminator Loss : 0.7152691
# Epoch 43 - Adverserial Loss : 0.6807257, Discriminator Loss : 0.7235957
# Epoch 44 - Adverserial Loss : 0.6838968, Discriminator Loss : 0.6780968
# Epoch 45 - Adverserial Loss : 0.7166579, Discriminator Loss : 0.64620036
# Epoch 46 - Adverserial Loss : 0.6825809, Discriminator Loss : 0.67392105
# Epoch 47 - Adverserial Loss : 0.71816576, Discriminator Loss : 0.6981425
# Epoch 48 - Adverserial Loss : 0.6822032, Discriminator Loss : 0.6797479
# Epoch 49 - Adverserial Loss : 0.68113106, Discriminator Loss : 0.6530193
# Epoch 50 - Adverserial Loss : 0.6671137, Discriminator Loss : 0.68653524
# Epoch 51 - Adverserial Loss : 0.6368778, Discriminator Loss : 0.7093515
# Epoch 52 - Adverserial Loss : 0.63445085, Discriminator Loss : 0.672356
# Epoch 53 - Adverserial Loss : 0.65509886, Discriminator Loss : 0.71263754
# Epoch 54 - Adverserial Loss : 0.6384151, Discriminator Loss : 0.76884425
# Epoch 55 - Adverserial Loss : 0.6917702, Discriminator Loss : 0.7297629
# Epoch 56 - Adverserial Loss : 0.6765564, Discriminator Loss : 0.69364417
# Epoch 57 - Adverserial Loss : 0.6909253, Discriminator Loss : 0.66177046
# Epoch 58 - Adverserial Loss : 0.67832565, Discriminator Loss : 0.6879171
# Epoch 59 - Adverserial Loss : 0.6760498, Discriminator Loss : 0.7218046
# Epoch 60 - Adverserial Loss : 0.7035964, Discriminator Loss : 0.7043133
# Epoch 61 - Adverserial Loss : 0.69649655, Discriminator Loss : 0.7100142
# Epoch 62 - Adverserial Loss : 0.6486332, Discriminator Loss : 0.6896261
# Epoch 63 - Adverserial Loss : 0.63539386, Discriminator Loss : 0.68421036
# Epoch 64 - Adverserial Loss : 0.6935986, Discriminator Loss : 0.6951238
# Epoch 65 - Adverserial Loss : 0.6737302, Discriminator Loss : 0.6924907
# Epoch 66 - Adverserial Loss : 0.6948018, Discriminator Loss : 0.7033261
# Epoch 67 - Adverserial Loss : 0.67411333, Discriminator Loss : 0.69718236
# Epoch 68 - Adverserial Loss : 0.66314673, Discriminator Loss : 0.6827026
# Epoch 69 - Adverserial Loss : 0.69674194, Discriminator Loss : 0.6881589
# Epoch 70 - Adverserial Loss : 0.665817, Discriminator Loss : 0.67334884
# Epoch 71 - Adverserial Loss : 0.65943193, Discriminator Loss : 0.7044457
# Epoch 72 - Adverserial Loss : 0.67205834, Discriminator Loss : 0.72835183
# Epoch 73 - Adverserial Loss : 0.65423894, Discriminator Loss : 0.6980368
# Epoch 74 - Adverserial Loss : 0.6458703, Discriminator Loss : 0.7145947
# Epoch 75 - Adverserial Loss : 0.6760472, Discriminator Loss : 0.7197797
# Epoch 76 - Adverserial Loss : 0.6985196, Discriminator Loss : 0.6813495
# Epoch 77 - Adverserial Loss : 0.69352627, Discriminator Loss : 0.65478414
# Epoch 78 - Adverserial Loss : 0.6805574, Discriminator Loss : 0.7172335
# Epoch 79 - Adverserial Loss : 0.6657486, Discriminator Loss : 0.6990474
# Epoch 80 - Adverserial Loss : 0.6651522, Discriminator Loss : 0.6635505
# Epoch 81 - Adverserial Loss : 0.7249789, Discriminator Loss : 0.6999186
# Epoch 82 - Adverserial Loss : 0.68900126, Discriminator Loss : 0.6871228
# Epoch 83 - Adverserial Loss : 0.66852266, Discriminator Loss : 0.7226136
# Epoch 84 - Adverserial Loss : 0.6484517, Discriminator Loss : 0.7302927
# Epoch 85 - Adverserial Loss : 0.66417235, Discriminator Loss : 0.74249744
# Epoch 86 - Adverserial Loss : 0.65073633, Discriminator Loss : 0.76642466
# Epoch 87 - Adverserial Loss : 0.6641896, Discriminator Loss : 0.7129636
# Epoch 88 - Adverserial Loss : 0.6600813, Discriminator Loss : 0.66619956
# Epoch 89 - Adverserial Loss : 0.6828618, Discriminator Loss : 0.6731278
# Epoch 90 - Adverserial Loss : 0.6685786, Discriminator Loss : 0.7126478
# Epoch 91 - Adverserial Loss : 0.6455392, Discriminator Loss : 0.6932074
# Epoch 92 - Adverserial Loss : 0.64461684, Discriminator Loss : 0.68477845
# Epoch 93 - Adverserial Loss : 0.6301019, Discriminator Loss : 0.71666574
# Epoch 94 - Adverserial Loss : 0.66272056, Discriminator Loss : 0.72690773
# Epoch 95 - Adverserial Loss : 0.6521019, Discriminator Loss : 0.73544663
# Epoch 96 - Adverserial Loss : 0.699592, Discriminator Loss : 0.7001866
# Epoch 97 - Adverserial Loss : 0.68521553, Discriminator Loss : 0.65992033
# Epoch 98 - Adverserial Loss : 0.6313962, Discriminator Loss : 0.68585336
# Epoch 99 - Adverserial Loss : 0.65422934, Discriminator Loss : 0.72161275
# Epoch 100 - Adverserial Loss : 0.6604898, Discriminator Loss : 0.7153097
# Epoch 101 - Adverserial Loss : 0.61536145, Discriminator Loss : 0.6816988
# Epoch 102 - Adverserial Loss : 0.636746, Discriminator Loss : 0.68452394
# Epoch 103 - Adverserial Loss : 0.65387475, Discriminator Loss : 0.6938112
# Epoch 104 - Adverserial Loss : 0.6405207, Discriminator Loss : 0.7008152
# Epoch 105 - Adverserial Loss : 0.64050835, Discriminator Loss : 0.7116653
# Epoch 106 - Adverserial Loss : 0.623747, Discriminator Loss : 0.70102626
# Epoch 107 - Adverserial Loss : 0.6398575, Discriminator Loss : 0.7078501
# Epoch 108 - Adverserial Loss : 0.6399713, Discriminator Loss : 0.7186396
# Epoch 109 - Adverserial Loss : 0.6696863, Discriminator Loss : 0.74567354
# Epoch 110 - Adverserial Loss : 0.7030601, Discriminator Loss : 0.72024643
# Epoch 111 - Adverserial Loss : 0.61336213, Discriminator Loss : 0.6875993
# Epoch 112 - Adverserial Loss : 0.63962936, Discriminator Loss : 0.7150164
# Epoch 113 - Adverserial Loss : 0.6201948, Discriminator Loss : 0.7000727
# Epoch 114 - Adverserial Loss : 0.5909257, Discriminator Loss : 0.67979753
# Epoch 115 - Adverserial Loss : 0.6562439, Discriminator Loss : 0.6859361
# Epoch 116 - Adverserial Loss : 0.6736952, Discriminator Loss : 0.6902146
# Epoch 117 - Adverserial Loss : 0.6605873, Discriminator Loss : 0.6892828
# Epoch 118 - Adverserial Loss : 0.6349666, Discriminator Loss : 0.672631
# Epoch 119 - Adverserial Loss : 0.63640976, Discriminator Loss : 0.66120076
# Epoch 120 - Adverserial Loss : 0.6614675, Discriminator Loss : 0.6763468
# Epoch 121 - Adverserial Loss : 0.6172097, Discriminator Loss : 0.6788645
# Epoch 122 - Adverserial Loss : 0.6783684, Discriminator Loss : 0.6717363
# Epoch 123 - Adverserial Loss : 0.6347053, Discriminator Loss : 0.6735417
# Epoch 124 - Adverserial Loss : 0.6442499, Discriminator Loss : 0.71207285
# Epoch 125 - Adverserial Loss : 0.63166916, Discriminator Loss : 0.72750044
# Epoch 126 - Adverserial Loss : 0.6167066, Discriminator Loss : 0.6792269
# Epoch 127 - Adverserial Loss : 0.6309002, Discriminator Loss : 0.6945399
# Epoch 128 - Adverserial Loss : 0.65333533, Discriminator Loss : 0.6977117
# Epoch 129 - Adverserial Loss : 0.6338166, Discriminator Loss : 0.6706724
# Epoch 130 - Adverserial Loss : 0.62966204, Discriminator Loss : 0.6919217
# Epoch 131 - Adverserial Loss : 0.65598965, Discriminator Loss : 0.6938075
# Epoch 132 - Adverserial Loss : 0.6644137, Discriminator Loss : 0.7058809
# Epoch 133 - Adverserial Loss : 0.6267065, Discriminator Loss : 0.7270777
# Epoch 134 - Adverserial Loss : 0.6092374, Discriminator Loss : 0.7234055
# Epoch 135 - Adverserial Loss : 0.65933293, Discriminator Loss : 0.7163509
# Epoch 136 - Adverserial Loss : 0.6599034, Discriminator Loss : 0.73377544
# Epoch 137 - Adverserial Loss : 0.645047, Discriminator Loss : 0.7109256
# Epoch 138 - Adverserial Loss : 0.6204943, Discriminator Loss : 0.70177734
# Epoch 139 - Adverserial Loss : 0.62798643, Discriminator Loss : 0.7303232
# Epoch 140 - Adverserial Loss : 0.6403302, Discriminator Loss : 0.72994745
# Epoch 141 - Adverserial Loss : 0.65483415, Discriminator Loss : 0.7094386
# Epoch 142 - Adverserial Loss : 0.6394659, Discriminator Loss : 0.69754446
# Epoch 143 - Adverserial Loss : 0.6468649, Discriminator Loss : 0.67948043
# Epoch 144 - Adverserial Loss : 0.6531575, Discriminator Loss : 0.6606108
# Epoch 145 - Adverserial Loss : 0.60142654, Discriminator Loss : 0.6750758
# Epoch 146 - Adverserial Loss : 0.6314688, Discriminator Loss : 0.67314315
# Epoch 147 - Adverserial Loss : 0.67171764, Discriminator Loss : 0.6989835
# Epoch 148 - Adverserial Loss : 0.6083369, Discriminator Loss : 0.72461796
# Epoch 149 - Adverserial Loss : 0.61669827, Discriminator Loss : 0.73603517
# Epoch 150 - Adverserial Loss : 0.63196814, Discriminator Loss : 0.7321534
# Epoch 151 - Adverserial Loss : 0.63040096, Discriminator Loss : 0.7139679
# Epoch 152 - Adverserial Loss : 0.62756824, Discriminator Loss : 0.71761173
# Epoch 153 - Adverserial Loss : 0.61709166, Discriminator Loss : 0.68194854
# Epoch 154 - Adverserial Loss : 0.664847, Discriminator Loss : 0.69690436
# Epoch 155 - Adverserial Loss : 0.6527991, Discriminator Loss : 0.7175379
# Epoch 156 - Adverserial Loss : 0.62548673, Discriminator Loss : 0.7272501
# Epoch 157 - Adverserial Loss : 0.64278364, Discriminator Loss : 0.7290778
# Epoch 158 - Adverserial Loss : 0.6262592, Discriminator Loss : 0.6901171
# Epoch 159 - Adverserial Loss : 0.63404584, Discriminator Loss : 0.7011306
# Epoch 160 - Adverserial Loss : 0.6388365, Discriminator Loss : 0.68944514
# Epoch 161 - Adverserial Loss : 0.6425582, Discriminator Loss : 0.7116003
# Epoch 162 - Adverserial Loss : 0.62842286, Discriminator Loss : 0.7314694
# Epoch 163 - Adverserial Loss : 0.64611685, Discriminator Loss : 0.73026025
# Epoch 164 - Adverserial Loss : 0.6188811, Discriminator Loss : 0.7105791
# Epoch 165 - Adverserial Loss : 0.6259277, Discriminator Loss : 0.6587584
# Epoch 166 - Adverserial Loss : 0.6268473, Discriminator Loss : 0.69856286
# Epoch 167 - Adverserial Loss : 0.627048, Discriminator Loss : 0.71206415
# Epoch 168 - Adverserial Loss : 0.6145526, Discriminator Loss : 0.6868218
# Epoch 169 - Adverserial Loss : 0.6451295, Discriminator Loss : 0.7087817
# Epoch 170 - Adverserial Loss : 0.63070446, Discriminator Loss : 0.7276639
# Epoch 171 - Adverserial Loss : 0.63451755, Discriminator Loss : 0.72419536
# Epoch 172 - Adverserial Loss : 0.6489419, Discriminator Loss : 0.725723
# Epoch 173 - Adverserial Loss : 0.60099065, Discriminator Loss : 0.7292897
# Epoch 174 - Adverserial Loss : 0.63002497, Discriminator Loss : 0.7294322
# Epoch 175 - Adverserial Loss : 0.6272544, Discriminator Loss : 0.70710814
# Epoch 176 - Adverserial Loss : 0.6068154, Discriminator Loss : 0.6830442
# Epoch 177 - Adverserial Loss : 0.63436466, Discriminator Loss : 0.696236
# Epoch 178 - Adverserial Loss : 0.6159004, Discriminator Loss : 0.6919657
# Epoch 179 - Adverserial Loss : 0.61428094, Discriminator Loss : 0.6763518
# Epoch 180 - Adverserial Loss : 0.62617826, Discriminator Loss : 0.6933195
# Epoch 181 - Adverserial Loss : 0.60648525, Discriminator Loss : 0.7044029
# Epoch 182 - Adverserial Loss : 0.5868554, Discriminator Loss : 0.6821928
# Epoch 183 - Adverserial Loss : 0.6350087, Discriminator Loss : 0.68995523
# Epoch 184 - Adverserial Loss : 0.5996126, Discriminator Loss : 0.69015265
# Epoch 185 - Adverserial Loss : 0.63592505, Discriminator Loss : 0.67215776
# Epoch 186 - Adverserial Loss : 0.6521063, Discriminator Loss : 0.6487666
# Epoch 187 - Adverserial Loss : 0.6319502, Discriminator Loss : 0.6629303
# Epoch 188 - Adverserial Loss : 0.6194561, Discriminator Loss : 0.71776444
# Epoch 189 - Adverserial Loss : 0.62607723, Discriminator Loss : 0.69670975
# Epoch 190 - Adverserial Loss : 0.628708, Discriminator Loss : 0.6890898
# Epoch 191 - Adverserial Loss : 0.6005663, Discriminator Loss : 0.70953715
# Epoch 192 - Adverserial Loss : 0.62129325, Discriminator Loss : 0.7351178
# Epoch 193 - Adverserial Loss : 0.6463307, Discriminator Loss : 0.72757196
# Epoch 194 - Adverserial Loss : 0.5780382, Discriminator Loss : 0.6806419
# Epoch 195 - Adverserial Loss : 0.6118263, Discriminator Loss : 0.70699656
# Epoch 196 - Adverserial Loss : 0.6381709, Discriminator Loss : 0.70397097
# Epoch 197 - Adverserial Loss : 0.6168984, Discriminator Loss : 0.6553208
# Epoch 198 - Adverserial Loss : 0.6186979, Discriminator Loss : 0.6821473
# Epoch 199 - Adverserial Loss : 0.58433723, Discriminator Loss : 0.70704913
# Epoch 200 - Adverserial Loss : 0.5980653, Discriminator Loss : 0.71250176
# Epoch 201 - Adverserial Loss : 0.6287374, Discriminator Loss : 0.7254317
# Epoch 202 - Adverserial Loss : 0.59995854, Discriminator Loss : 0.7276163
# Epoch 203 - Adverserial Loss : 0.61838734, Discriminator Loss : 0.7361597
# Epoch 204 - Adverserial Loss : 0.58970666, Discriminator Loss : 0.7452099
# Epoch 205 - Adverserial Loss : 0.59700924, Discriminator Loss : 0.7127308
# Epoch 206 - Adverserial Loss : 0.6079515, Discriminator Loss : 0.67973626
# Epoch 207 - Adverserial Loss : 0.6189499, Discriminator Loss : 0.7150742
# Epoch 208 - Adverserial Loss : 0.66073334, Discriminator Loss : 0.7113491
# Epoch 209 - Adverserial Loss : 0.60455924, Discriminator Loss : 0.6946918
# Epoch 210 - Adverserial Loss : 0.64116955, Discriminator Loss : 0.7301333
# Epoch 211 - Adverserial Loss : 0.6566918, Discriminator Loss : 0.6803063
# Epoch 212 - Adverserial Loss : 0.6042137, Discriminator Loss : 0.6574812
# Epoch 213 - Adverserial Loss : 0.6173867, Discriminator Loss : 0.7181254
# Epoch 214 - Adverserial Loss : 0.6098776, Discriminator Loss : 0.7198339
# Epoch 215 - Adverserial Loss : 0.61376405, Discriminator Loss : 0.7212537
# Epoch 216 - Adverserial Loss : 0.6264975, Discriminator Loss : 0.72014225
# Epoch 217 - Adverserial Loss : 0.6349009, Discriminator Loss : 0.679573
# Epoch 218 - Adverserial Loss : 0.61660874, Discriminator Loss : 0.68126905
# Epoch 219 - Adverserial Loss : 0.6401545, Discriminator Loss : 0.6924511
# Epoch 220 - Adverserial Loss : 0.6091929, Discriminator Loss : 0.6709732
# Epoch 221 - Adverserial Loss : 0.628716, Discriminator Loss : 0.70816004
# Epoch 222 - Adverserial Loss : 0.6373246, Discriminator Loss : 0.7245753
# Epoch 223 - Adverserial Loss : 0.5953165, Discriminator Loss : 0.700293
# Epoch 224 - Adverserial Loss : 0.60621405, Discriminator Loss : 0.686089
# Epoch 225 - Adverserial Loss : 0.57373315, Discriminator Loss : 0.6725419
# Epoch 226 - Adverserial Loss : 0.61039525, Discriminator Loss : 0.6979083
# Epoch 227 - Adverserial Loss : 0.6391886, Discriminator Loss : 0.6957452
# Epoch 228 - Adverserial Loss : 0.6077394, Discriminator Loss : 0.68140525
# Epoch 229 - Adverserial Loss : 0.6139508, Discriminator Loss : 0.68398386
# Epoch 230 - Adverserial Loss : 0.5919621, Discriminator Loss : 0.67471707
# Epoch 231 - Adverserial Loss : 0.6711421, Discriminator Loss : 0.6674968
# Epoch 232 - Adverserial Loss : 0.62290376, Discriminator Loss : 0.6779352
# Epoch 233 - Adverserial Loss : 0.65000093, Discriminator Loss : 0.6825742
# Epoch 234 - Adverserial Loss : 0.61738294, Discriminator Loss : 0.6819666
# Epoch 235 - Adverserial Loss : 0.6063523, Discriminator Loss : 0.7291107
# Epoch 236 - Adverserial Loss : 0.59917426, Discriminator Loss : 0.7027683
# Epoch 237 - Adverserial Loss : 0.612478, Discriminator Loss : 0.6580717
# Epoch 238 - Adverserial Loss : 0.58863866, Discriminator Loss : 0.6619445
# Epoch 239 - Adverserial Loss : 0.63860035, Discriminator Loss : 0.6787542
# Epoch 240 - Adverserial Loss : 0.6128602, Discriminator Loss : 0.6975331
# Epoch 241 - Adverserial Loss : 0.6376193, Discriminator Loss : 0.69178295
# Epoch 242 - Adverserial Loss : 0.6327857, Discriminator Loss : 0.69037396
# Epoch 243 - Adverserial Loss : 0.5880764, Discriminator Loss : 0.68022746
# Epoch 244 - Adverserial Loss : 0.6420536, Discriminator Loss : 0.6916735
# Epoch 245 - Adverserial Loss : 0.63602537, Discriminator Loss : 0.72687185
# Epoch 246 - Adverserial Loss : 0.62557197, Discriminator Loss : 0.70038235
# Epoch 247 - Adverserial Loss : 0.59964424, Discriminator Loss : 0.7199453
# Epoch 248 - Adverserial Loss : 0.6193595, Discriminator Loss : 0.72310776
# Epoch 249 - Adverserial Loss : 0.5849248, Discriminator Loss : 0.6763309
# Epoch 250 - Adverserial Loss : 0.6147666, Discriminator Loss : 0.683637
# Epoch 251 - Adverserial Loss : 0.61053395, Discriminator Loss : 0.68413895
# Epoch 252 - Adverserial Loss : 0.6125227, Discriminator Loss : 0.6904369
# Epoch 253 - Adverserial Loss : 0.5813029, Discriminator Loss : 0.6808082
# Epoch 254 - Adverserial Loss : 0.60561705, Discriminator Loss : 0.6692656
# Epoch 255 - Adverserial Loss : 0.6078079, Discriminator Loss : 0.68493277
# Epoch 256 - Adverserial Loss : 0.6243053, Discriminator Loss : 0.7048851
# Epoch 257 - Adverserial Loss : 0.6128627, Discriminator Loss : 0.705938
# Epoch 258 - Adverserial Loss : 0.6164517, Discriminator Loss : 0.70290625
# Epoch 259 - Adverserial Loss : 0.5982597, Discriminator Loss : 0.70003766
# Epoch 260 - Adverserial Loss : 0.6153964, Discriminator Loss : 0.6982647
# Epoch 261 - Adverserial Loss : 0.6267246, Discriminator Loss : 0.6948987
# Epoch 262 - Adverserial Loss : 0.63096535, Discriminator Loss : 0.67461556
# Epoch 263 - Adverserial Loss : 0.5855298, Discriminator Loss : 0.6836091
# Epoch 264 - Adverserial Loss : 0.6111767, Discriminator Loss : 0.7125335
# Epoch 265 - Adverserial Loss : 0.60268664, Discriminator Loss : 0.7049421
# Epoch 266 - Adverserial Loss : 0.63044417, Discriminator Loss : 0.6974776
# Epoch 267 - Adverserial Loss : 0.60451823, Discriminator Loss : 0.6905528
# Epoch 268 - Adverserial Loss : 0.5826687, Discriminator Loss : 0.7048582
# Epoch 269 - Adverserial Loss : 0.6068331, Discriminator Loss : 0.72895217
# Epoch 270 - Adverserial Loss : 0.6102605, Discriminator Loss : 0.6986009
# Epoch 271 - Adverserial Loss : 0.56183517, Discriminator Loss : 0.69256586
# Epoch 272 - Adverserial Loss : 0.62631065, Discriminator Loss : 0.7017988
# Epoch 273 - Adverserial Loss : 0.60957515, Discriminator Loss : 0.63624924
# Epoch 274 - Adverserial Loss : 0.610158, Discriminator Loss : 0.6284226
# Epoch 275 - Adverserial Loss : 0.6184274, Discriminator Loss : 0.66798747
# Epoch 276 - Adverserial Loss : 0.6011581, Discriminator Loss : 0.68805444
# Epoch 277 - Adverserial Loss : 0.57693803, Discriminator Loss : 0.7076268
# Epoch 278 - Adverserial Loss : 0.612588, Discriminator Loss : 0.69157964
# Epoch 279 - Adverserial Loss : 0.61693907, Discriminator Loss : 0.6851046
# Epoch 280 - Adverserial Loss : 0.6213603, Discriminator Loss : 0.6850883
# Epoch 281 - Adverserial Loss : 0.5833058, Discriminator Loss : 0.659342
# Epoch 282 - Adverserial Loss : 0.6295708, Discriminator Loss : 0.64599293
# Epoch 283 - Adverserial Loss : 0.6385516, Discriminator Loss : 0.6708173
# Epoch 284 - Adverserial Loss : 0.59110135, Discriminator Loss : 0.682979
# Epoch 285 - Adverserial Loss : 0.6159524, Discriminator Loss : 0.6865684
# Epoch 286 - Adverserial Loss : 0.6175151, Discriminator Loss : 0.6889954
# Epoch 287 - Adverserial Loss : 0.5865505, Discriminator Loss : 0.68161535
# Epoch 288 - Adverserial Loss : 0.5903558, Discriminator Loss : 0.69207656
# Epoch 289 - Adverserial Loss : 0.6197577, Discriminator Loss : 0.73539126
# Epoch 290 - Adverserial Loss : 0.5980525, Discriminator Loss : 0.72355247
# Epoch 291 - Adverserial Loss : 0.5718088, Discriminator Loss : 0.6833098
# Epoch 292 - Adverserial Loss : 0.6142391, Discriminator Loss : 0.68008864
# Epoch 293 - Adverserial Loss : 0.62196505, Discriminator Loss : 0.6868353
# Epoch 294 - Adverserial Loss : 0.5974119, Discriminator Loss : 0.690728
# Epoch 295 - Adverserial Loss : 0.5983937, Discriminator Loss : 0.6931038
# Epoch 296 - Adverserial Loss : 0.6319016, Discriminator Loss : 0.70106614
# Epoch 297 - Adverserial Loss : 0.5762038, Discriminator Loss : 0.6940483
# Epoch 298 - Adverserial Loss : 0.58951926, Discriminator Loss : 0.6801114
# Epoch 299 - Adverserial Loss : 0.62038994, Discriminator Loss : 0.67533946
# Epoch 300 - Adverserial Loss : 0.6251857, Discriminator Loss : 0.6752142
# Epoch 301 - Adverserial Loss : 0.6154064, Discriminator Loss : 0.6529625
# Epoch 302 - Adverserial Loss : 0.6123952, Discriminator Loss : 0.64555275
# Epoch 303 - Adverserial Loss : 0.6055893, Discriminator Loss : 0.66630423
# Epoch 304 - Adverserial Loss : 0.6030703, Discriminator Loss : 0.66501486
# Epoch 305 - Adverserial Loss : 0.58324707, Discriminator Loss : 0.6857004
# Epoch 306 - Adverserial Loss : 0.601853, Discriminator Loss : 0.69693863
# Epoch 307 - Adverserial Loss : 0.61894286, Discriminator Loss : 0.6530353
# Epoch 308 - Adverserial Loss : 0.5787842, Discriminator Loss : 0.6748078
# Epoch 309 - Adverserial Loss : 0.5907546, Discriminator Loss : 0.70472735
# Epoch 310 - Adverserial Loss : 0.60938966, Discriminator Loss : 0.68289244
# Epoch 311 - Adverserial Loss : 0.5986207, Discriminator Loss : 0.65346855
# Epoch 312 - Adverserial Loss : 0.6185508, Discriminator Loss : 0.6431231
# Epoch 313 - Adverserial Loss : 0.61544186, Discriminator Loss : 0.6898724
# Epoch 314 - Adverserial Loss : 0.58867174, Discriminator Loss : 0.68727076
# Epoch 315 - Adverserial Loss : 0.57990104, Discriminator Loss : 0.66664755
# Epoch 316 - Adverserial Loss : 0.6099415, Discriminator Loss : 0.7130687
# Epoch 317 - Adverserial Loss : 0.57386494, Discriminator Loss : 0.70867324
# Epoch 318 - Adverserial Loss : 0.6229889, Discriminator Loss : 0.68098116
# Epoch 319 - Adverserial Loss : 0.5790988, Discriminator Loss : 0.70198727
# Epoch 320 - Adverserial Loss : 0.5702539, Discriminator Loss : 0.6584241
# Epoch 321 - Adverserial Loss : 0.644307, Discriminator Loss : 0.6106675
# Epoch 322 - Adverserial Loss : 0.6367681, Discriminator Loss : 0.63925576
# Epoch 323 - Adverserial Loss : 0.56542945, Discriminator Loss : 0.66039205
# Epoch 324 - Adverserial Loss : 0.5592916, Discriminator Loss : 0.6828104
# Epoch 325 - Adverserial Loss : 0.5752431, Discriminator Loss : 0.6948062
# Epoch 326 - Adverserial Loss : 0.6058878, Discriminator Loss : 0.65267015
# Epoch 327 - Adverserial Loss : 0.58880806, Discriminator Loss : 0.6603132
# Epoch 328 - Adverserial Loss : 0.5875362, Discriminator Loss : 0.69688445
# Epoch 329 - Adverserial Loss : 0.57970583, Discriminator Loss : 0.71238136
# Epoch 330 - Adverserial Loss : 0.57786185, Discriminator Loss : 0.69724584
# Epoch 331 - Adverserial Loss : 0.6015139, Discriminator Loss : 0.6421179
# Epoch 332 - Adverserial Loss : 0.5736925, Discriminator Loss : 0.62376463
# Epoch 333 - Adverserial Loss : 0.57309884, Discriminator Loss : 0.6883687
# Epoch 334 - Adverserial Loss : 0.56277007, Discriminator Loss : 0.7244245
# Epoch 335 - Adverserial Loss : 0.6270583, Discriminator Loss : 0.73380697
# Epoch 336 - Adverserial Loss : 0.58855444, Discriminator Loss : 0.72750616
# Epoch 337 - Adverserial Loss : 0.5741048, Discriminator Loss : 0.6912035
# Epoch 338 - Adverserial Loss : 0.581385, Discriminator Loss : 0.69881046
# Epoch 339 - Adverserial Loss : 0.6116563, Discriminator Loss : 0.68135816
# Epoch 340 - Adverserial Loss : 0.5913485, Discriminator Loss : 0.68145806
# Epoch 341 - Adverserial Loss : 0.6227477, Discriminator Loss : 0.68034446
# Epoch 342 - Adverserial Loss : 0.6226987, Discriminator Loss : 0.6933929
# Epoch 343 - Adverserial Loss : 0.58960927, Discriminator Loss : 0.72929925
# Epoch 344 - Adverserial Loss : 0.63713336, Discriminator Loss : 0.7309754
# Epoch 345 - Adverserial Loss : 0.5902475, Discriminator Loss : 0.71100175
# Epoch 346 - Adverserial Loss : 0.5998826, Discriminator Loss : 0.6775486
# Epoch 347 - Adverserial Loss : 0.58342975, Discriminator Loss : 0.68644655
# Epoch 348 - Adverserial Loss : 0.5721493, Discriminator Loss : 0.6912506
# Epoch 349 - Adverserial Loss : 0.5894454, Discriminator Loss : 0.7082455
# Epoch 350 - Adverserial Loss : 0.5870169, Discriminator Loss : 0.69657516
# Epoch 351 - Adverserial Loss : 0.5903653, Discriminator Loss : 0.6323681
# Epoch 352 - Adverserial Loss : 0.606125, Discriminator Loss : 0.6444925
# Epoch 353 - Adverserial Loss : 0.6099578, Discriminator Loss : 0.6838844
# Epoch 354 - Adverserial Loss : 0.6057604, Discriminator Loss : 0.69635236
# Epoch 355 - Adverserial Loss : 0.622988, Discriminator Loss : 0.66373795
# Epoch 356 - Adverserial Loss : 0.6000583, Discriminator Loss : 0.6461897
# Epoch 357 - Adverserial Loss : 0.6110245, Discriminator Loss : 0.6696472
# Epoch 358 - Adverserial Loss : 0.57224476, Discriminator Loss : 0.68009734
# Epoch 359 - Adverserial Loss : 0.5694572, Discriminator Loss : 0.67697847
# Epoch 360 - Adverserial Loss : 0.5812277, Discriminator Loss : 0.6943892
# Epoch 361 - Adverserial Loss : 0.6087069, Discriminator Loss : 0.71085787
# Epoch 362 - Adverserial Loss : 0.6186131, Discriminator Loss : 0.70249987
# Epoch 363 - Adverserial Loss : 0.59530675, Discriminator Loss : 0.7115783
# Epoch 364 - Adverserial Loss : 0.6122602, Discriminator Loss : 0.70838976
# Epoch 365 - Adverserial Loss : 0.55225354, Discriminator Loss : 0.6938396
# Epoch 366 - Adverserial Loss : 0.5775876, Discriminator Loss : 0.71475434
# Epoch 367 - Adverserial Loss : 0.5654585, Discriminator Loss : 0.697488
# Epoch 368 - Adverserial Loss : 0.5867823, Discriminator Loss : 0.6450485
# Epoch 369 - Adverserial Loss : 0.57058424, Discriminator Loss : 0.66464084
# Epoch 370 - Adverserial Loss : 0.5679656, Discriminator Loss : 0.7201009
# Epoch 371 - Adverserial Loss : 0.6040278, Discriminator Loss : 0.7419148
# Epoch 372 - Adverserial Loss : 0.57216233, Discriminator Loss : 0.7126758
# Epoch 373 - Adverserial Loss : 0.5852745, Discriminator Loss : 0.6745462
# Epoch 374 - Adverserial Loss : 0.5324886, Discriminator Loss : 0.6821952
# Epoch 375 - Adverserial Loss : 0.5689073, Discriminator Loss : 0.6885152
# Epoch 376 - Adverserial Loss : 0.5574571, Discriminator Loss : 0.67495537
# Epoch 377 - Adverserial Loss : 0.6134505, Discriminator Loss : 0.70000196
# Epoch 378 - Adverserial Loss : 0.59368956, Discriminator Loss : 0.71673787
# Epoch 379 - Adverserial Loss : 0.6000692, Discriminator Loss : 0.71263754
# Epoch 380 - Adverserial Loss : 0.5912286, Discriminator Loss : 0.6737051
# Epoch 381 - Adverserial Loss : 0.59250337, Discriminator Loss : 0.65844893
# Epoch 382 - Adverserial Loss : 0.5989646, Discriminator Loss : 0.69293773
# Epoch 383 - Adverserial Loss : 0.61835766, Discriminator Loss : 0.6637587
# Epoch 384 - Adverserial Loss : 0.5683445, Discriminator Loss : 0.67617357
# Epoch 385 - Adverserial Loss : 0.5915915, Discriminator Loss : 0.71061516
# Epoch 386 - Adverserial Loss : 0.5829604, Discriminator Loss : 0.700583
# Epoch 387 - Adverserial Loss : 0.6029022, Discriminator Loss : 0.6885737
# Epoch 388 - Adverserial Loss : 0.61618173, Discriminator Loss : 0.6908825
# Epoch 389 - Adverserial Loss : 0.5980027, Discriminator Loss : 0.66445357
# Epoch 390 - Adverserial Loss : 0.5733092, Discriminator Loss : 0.67715895
# Epoch 391 - Adverserial Loss : 0.55466056, Discriminator Loss : 0.73969376
# Epoch 392 - Adverserial Loss : 0.5698445, Discriminator Loss : 0.7147191
# Epoch 393 - Adverserial Loss : 0.5912132, Discriminator Loss : 0.69356596
# Epoch 394 - Adverserial Loss : 0.5896597, Discriminator Loss : 0.6822667
# Epoch 395 - Adverserial Loss : 0.58261806, Discriminator Loss : 0.6668985
# Epoch 396 - Adverserial Loss : 0.61814666, Discriminator Loss : 0.6556967
# Epoch 397 - Adverserial Loss : 0.57988036, Discriminator Loss : 0.6660831
# Epoch 398 - Adverserial Loss : 0.6165216, Discriminator Loss : 0.6741105
# Epoch 399 - Adverserial Loss : 0.56747794, Discriminator Loss : 0.655597
# Epoch 400 - Adverserial Loss : 0.5447778, Discriminator Loss : 0.67503256
# Epoch 401 - Adverserial Loss : 0.6000389, Discriminator Loss : 0.7159287
# Epoch 402 - Adverserial Loss : 0.5949132, Discriminator Loss : 0.71347094
# Epoch 403 - Adverserial Loss : 0.5683754, Discriminator Loss : 0.6886738
# Epoch 404 - Adverserial Loss : 0.5925659, Discriminator Loss : 0.6614801
# Epoch 405 - Adverserial Loss : 0.6162096, Discriminator Loss : 0.6898323
# Epoch 406 - Adverserial Loss : 0.6262359, Discriminator Loss : 0.697099
# Epoch 407 - Adverserial Loss : 0.5783581, Discriminator Loss : 0.66034204
# Epoch 408 - Adverserial Loss : 0.5877178, Discriminator Loss : 0.6841141
# Epoch 409 - Adverserial Loss : 0.57377934, Discriminator Loss : 0.6823131
# Epoch 410 - Adverserial Loss : 0.5551558, Discriminator Loss : 0.67396677
# Epoch 411 - Adverserial Loss : 0.594118, Discriminator Loss : 0.6868106
# Epoch 412 - Adverserial Loss : 0.5930202, Discriminator Loss : 0.68125594
# Epoch 413 - Adverserial Loss : 0.5819581, Discriminator Loss : 0.6796837
# Epoch 414 - Adverserial Loss : 0.53475857, Discriminator Loss : 0.6821863
# Epoch 415 - Adverserial Loss : 0.5644851, Discriminator Loss : 0.6802497
# Epoch 416 - Adverserial Loss : 0.5967575, Discriminator Loss : 0.7171238
# Epoch 417 - Adverserial Loss : 0.54693216, Discriminator Loss : 0.71521246
# Epoch 418 - Adverserial Loss : 0.56302035, Discriminator Loss : 0.68943703
# Epoch 419 - Adverserial Loss : 0.5681697, Discriminator Loss : 0.68857366
# Epoch 420 - Adverserial Loss : 0.5868499, Discriminator Loss : 0.6789025
# Epoch 421 - Adverserial Loss : 0.5851857, Discriminator Loss : 0.6718266
# Epoch 422 - Adverserial Loss : 0.5880519, Discriminator Loss : 0.68530303
# Epoch 423 - Adverserial Loss : 0.5924033, Discriminator Loss : 0.7145084
# Epoch 424 - Adverserial Loss : 0.5899426, Discriminator Loss : 0.7089239
# Epoch 425 - Adverserial Loss : 0.5862354, Discriminator Loss : 0.6849668
# Epoch 426 - Adverserial Loss : 0.55214405, Discriminator Loss : 0.7068738
# Epoch 427 - Adverserial Loss : 0.58821124, Discriminator Loss : 0.7114038
# Epoch 428 - Adverserial Loss : 0.5406946, Discriminator Loss : 0.68687344
# Epoch 429 - Adverserial Loss : 0.57338613, Discriminator Loss : 0.702355
# Epoch 430 - Adverserial Loss : 0.57299435, Discriminator Loss : 0.6906667
# Epoch 431 - Adverserial Loss : 0.5267377, Discriminator Loss : 0.7095371
# Epoch 432 - Adverserial Loss : 0.5833366, Discriminator Loss : 0.71586
# Epoch 433 - Adverserial Loss : 0.5707389, Discriminator Loss : 0.6730664
# Epoch 434 - Adverserial Loss : 0.5381727, Discriminator Loss : 0.6932237
# Epoch 435 - Adverserial Loss : 0.5688658, Discriminator Loss : 0.66746986
# Epoch 436 - Adverserial Loss : 0.55905247, Discriminator Loss : 0.6697599
# Epoch 437 - Adverserial Loss : 0.5887103, Discriminator Loss : 0.68851984
# Epoch 438 - Adverserial Loss : 0.58636796, Discriminator Loss : 0.66959155
# Epoch 439 - Adverserial Loss : 0.5813991, Discriminator Loss : 0.66190886
# Epoch 440 - Adverserial Loss : 0.5744715, Discriminator Loss : 0.6666468
# Epoch 441 - Adverserial Loss : 0.5536313, Discriminator Loss : 0.7066028
# Epoch 442 - Adverserial Loss : 0.5404575, Discriminator Loss : 0.70376027
# Epoch 443 - Adverserial Loss : 0.57420266, Discriminator Loss : 0.697399
# Epoch 444 - Adverserial Loss : 0.5652838, Discriminator Loss : 0.67632604
# Epoch 445 - Adverserial Loss : 0.57879394, Discriminator Loss : 0.6673824
# Epoch 446 - Adverserial Loss : 0.57868654, Discriminator Loss : 0.7000592
# Epoch 447 - Adverserial Loss : 0.5722751, Discriminator Loss : 0.70033026
# Epoch 448 - Adverserial Loss : 0.6041399, Discriminator Loss : 0.7187338
# Epoch 449 - Adverserial Loss : 0.57197917, Discriminator Loss : 0.71189606
# Epoch 450 - Adverserial Loss : 0.52951133, Discriminator Loss : 0.6897571
# Epoch 451 - Adverserial Loss : 0.5486525, Discriminator Loss : 0.71578753
# Epoch 452 - Adverserial Loss : 0.5935993, Discriminator Loss : 0.72233033
# Epoch 453 - Adverserial Loss : 0.6031664, Discriminator Loss : 0.689811
# Epoch 454 - Adverserial Loss : 0.5507154, Discriminator Loss : 0.658049
# Epoch 455 - Adverserial Loss : 0.56434613, Discriminator Loss : 0.74016273
# Epoch 456 - Adverserial Loss : 0.56368345, Discriminator Loss : 0.77675605
# Epoch 457 - Adverserial Loss : 0.5559895, Discriminator Loss : 0.66117585
# Epoch 458 - Adverserial Loss : 0.5644894, Discriminator Loss : 0.6528442
# Epoch 459 - Adverserial Loss : 0.54982615, Discriminator Loss : 0.71134794
# Epoch 460 - Adverserial Loss : 0.5696553, Discriminator Loss : 0.7114428
# Epoch 461 - Adverserial Loss : 0.5278839, Discriminator Loss : 0.6748923
# Epoch 462 - Adverserial Loss : 0.57039356, Discriminator Loss : 0.6626449
# Epoch 463 - Adverserial Loss : 0.5518574, Discriminator Loss : 0.67515355
# Epoch 464 - Adverserial Loss : 0.58958757, Discriminator Loss : 0.701882
# Epoch 465 - Adverserial Loss : 0.55770606, Discriminator Loss : 0.7238263
# Epoch 466 - Adverserial Loss : 0.60028404, Discriminator Loss : 0.6916193
# Epoch 467 - Adverserial Loss : 0.57362056, Discriminator Loss : 0.6658552
# Epoch 468 - Adverserial Loss : 0.56454283, Discriminator Loss : 0.6773696
# Epoch 469 - Adverserial Loss : 0.5447798, Discriminator Loss : 0.6883685
# Epoch 470 - Adverserial Loss : 0.55671763, Discriminator Loss : 0.680285
# Epoch 471 - Adverserial Loss : 0.55328465, Discriminator Loss : 0.6832178
# Epoch 472 - Adverserial Loss : 0.56890595, Discriminator Loss : 0.69744086
# Epoch 473 - Adverserial Loss : 0.5700835, Discriminator Loss : 0.701782
# Epoch 474 - Adverserial Loss : 0.57112235, Discriminator Loss : 0.6906616
# Epoch 475 - Adverserial Loss : 0.5730529, Discriminator Loss : 0.68880606
# Epoch 476 - Adverserial Loss : 0.5702962, Discriminator Loss : 0.7125691
# Epoch 477 - Adverserial Loss : 0.5913484, Discriminator Loss : 0.69436204
# Epoch 478 - Adverserial Loss : 0.5377704, Discriminator Loss : 0.6413729
# Epoch 479 - Adverserial Loss : 0.5739264, Discriminator Loss : 0.6663841
# Epoch 480 - Adverserial Loss : 0.5819463, Discriminator Loss : 0.7012272
# Epoch 481 - Adverserial Loss : 0.5801538, Discriminator Loss : 0.68924326
# Epoch 482 - Adverserial Loss : 0.58759874, Discriminator Loss : 0.68319094
# Epoch 483 - Adverserial Loss : 0.5600195, Discriminator Loss : 0.67987365
# Epoch 484 - Adverserial Loss : 0.567014, Discriminator Loss : 0.6914253
# Epoch 485 - Adverserial Loss : 0.5680388, Discriminator Loss : 0.66196656
# Epoch 486 - Adverserial Loss : 0.5419202, Discriminator Loss : 0.6677934
# Epoch 487 - Adverserial Loss : 0.55239356, Discriminator Loss : 0.70609677
# Epoch 488 - Adverserial Loss : 0.5291775, Discriminator Loss : 0.69111514
# Epoch 489 - Adverserial Loss : 0.55681723, Discriminator Loss : 0.7207625
# Epoch 490 - Adverserial Loss : 0.55867827, Discriminator Loss : 0.71483886
# Epoch 491 - Adverserial Loss : 0.549847, Discriminator Loss : 0.6827157
# Epoch 492 - Adverserial Loss : 0.5645717, Discriminator Loss : 0.69270223
# Epoch 493 - Adverserial Loss : 0.5901692, Discriminator Loss : 0.70207787
# Epoch 494 - Adverserial Loss : 0.5561235, Discriminator Loss : 0.70559835
# Epoch 495 - Adverserial Loss : 0.587337, Discriminator Loss : 0.7170211
# Epoch 496 - Adverserial Loss : 0.57430285, Discriminator Loss : 0.7210313
# Epoch 497 - Adverserial Loss : 0.5669589, Discriminator Loss : 0.71935534
# Epoch 498 - Adverserial Loss : 0.55506885, Discriminator Loss : 0.70515066
# Epoch 499 - Adverserial Loss : 0.5727023, Discriminator Loss : 0.68107843
# Epoch 500 - Adverserial Loss : 0.58794403, Discriminator Loss : 0.67941433

# %%
fig = plt.figure(figsize=(13,7))
plt.title("Loss Function over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(loss["g"], label="Adverserial Loss")
plt.plot(loss["d"], label="Discriminitve Loss")
plt.legend()
plt.show()

# %%
network.predict([0.1,0.2,0.1,0.1,0.1,0.1])
# Out:
# array([-0.18420246, -0.15940762, -0.1435323 ,  0.00080283], dtype=float32)

# %%
network.generator.summary()
network.discriminator.summary()
network.adverserial.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Generator_Input (InputLayer) (None, 6)                 0
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                112
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 16)                272
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16)                0
# _________________________________________________________________
# Generator_Output (Dense)     (None, 4)                 68
# =================================================================
# Total params: 452
# Trainable params: 452
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Discriminator_Input (InputLa (None, 10)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 16)                176
# _________________________________________________________________
# dense_7 (Dense)              (None, 16)                272
# _________________________________________________________________
# Discriminator_Output (Dense) (None, 1)                 17
# =================================================================
# Total params: 465
# Trainable params: 465
# Non-trainable params: 0
# _________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Generator_Input (InputLayer)    (None, 6)            0
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 16)           112         Generator_Input[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 16)           272         dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# Generator_Output (Dense)        (None, 4)            68          dropout_3[0][0]
# __________________________________________________________________________________________________
# Generator_Input_Output (Concate (None, 10)           0           Generator_Input[0][0]
#                                                                  Generator_Output[0][0]
# __________________________________________________________________________________________________
# Discriminator (Model)           (None, 1)            465         Generator_Input_Output[0][0]
# ==================================================================================================
# Total params: 917
# Trainable params: 917
# Non-trainable params: 0
# __________________________________________________________________________________________________
